# %%
import pandas as pd

# %%
#d_parser = lambda x: pd.datetime.strptime(x,'%Y-%m-%d  %I-%p')
df = pd.read_csv('E:\Kaggle DB\Extracted\ETH Data\ETH_1H.csv',date_parser=['Date'])
df.head(100)
# Out:
#     Unix Timestamp                 Date  Symbol    Open    High     Low  \
# 0    1586995200000  2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39
# 1    1586991600000  2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39
# 2    1586988000000  2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32
# 3    1586984400000  2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16
# 4    1586980800000  2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87
# ..             ...                  ...     ...     ...     ...     ...
# 95   1586653200000  2020-04-12 01:00:00  ETHUSD  157.89  158.41  157.54
# 96   1586649600000  2020-04-12 00:00:00  ETHUSD  158.66  159.66  157.89
# 97   1586646000000  2020-04-11 23:00:00  ETHUSD  158.20  158.91  157.32
# 98   1586642400000  2020-04-11 22:00:00  ETHUSD  157.38  158.91  157.38
# 99   1586638800000  2020-04-11 21:00:00  ETHUSD  155.02  157.38  154.72
#
#      Close       Volume
# 0   150.39   650.188125
# 1   152.94  4277.567299
# 2   155.81   106.337279
# ...

# %%
df.shape
# Out:
# (34497, 8)

# %%
df.loc[0,'Date']  #For one DataSet
# Out:
# '2020-04-16 00:00:00'

# %%
df.loc[[0,2],['Date','Open','High','Low','Close','Volume']]

#This above code determines that 0 and 2nd day Open, high, close, low and Volume for which the stock was brought
#with the date
# Out:
#                   Date    Open    High     Low   Close      Volume
# 0  2020-04-16 00:00:00  152.94  152.94  150.39  150.39  650.188125
# 2  2020-04-15 22:00:00  157.18  157.30  155.32  155.81  106.337279

# %%
df['Date'] = pd.to_datetime(df['Date']).dt.strftime('%d-%m-%Y   %X')

# %%
df['Date'].head(10)
# Out:
# 0    16-04-2020   00:00:00
# 1    15-04-2020   23:00:00
# 2    15-04-2020   22:00:00
# 3    15-04-2020   21:00:00
# 4    15-04-2020   20:00:00
# 5    15-04-2020   19:00:00
# 6    15-04-2020   18:00:00
# 7    15-04-2020   17:00:00
# 8    15-04-2020   16:00:00
# 9    15-04-2020   15:00:00
# Name: Date, dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.loc[0,'Date'].day_name()
# Out:
# 'Thursday'

# %%
df['Date'].min()
# Out:
# Timestamp('2016-01-06 00:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2020-12-04 23:00:00')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('1794 days 23:00:00')

# %%
filt = (df['Date']>= pd.to_datetime('2019-01-01')) & (df['Date']< pd.to_datetime('2020'))
df[filt]
# Out:
#        Unix Timestamp                Date  Symbol    Open    High     Low  \
# 2545    1577833200000 2019-12-31 23:00:00  ETHUSD  128.68  128.85  127.82
# 2546    1577829600000 2019-12-31 22:00:00  ETHUSD  128.40  128.93  127.77
# 2547    1577826000000 2019-12-31 21:00:00  ETHUSD  127.87  128.41  127.81
# 2548    1577822400000 2019-12-31 20:00:00  ETHUSD  127.86  128.30  127.86
# 2549    1577818800000 2019-12-31 19:00:00  ETHUSD  128.78  128.78  127.86
# ...               ...                 ...     ...     ...     ...     ...
# 11297   1546315200000 2019-01-01 04:00:00  ETHUSD  130.83  133.75  130.83
# 11298   1546311600000 2019-01-01 03:00:00  ETHUSD  129.79  131.00  129.79
# 11299   1546308000000 2019-01-01 02:00:00  ETHUSD  130.98  130.98  129.25
# 11300   1546304400000 2019-01-01 01:00:00  ETHUSD  131.10  131.10  128.72
# 11301   1546300800000 2019-01-01 00:00:00  ETHUSD  130.80  131.70  130.00
#
#         Close       Volume
# 2545   128.84   857.650259
# ...

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-04-16 00:00:00   1586995200000  ETHUSD  152.94  152.94  150.39  150.39
# 2020-04-15 23:00:00   1586991600000  ETHUSD  155.81  155.81  151.39  152.94
# 2020-04-15 22:00:00   1586988000000  ETHUSD  157.18  157.30  155.32  155.81
# 2020-04-15 21:00:00   1586984400000  ETHUSD  158.04  158.31  157.16  157.18
# 2020-04-15 20:00:00   1586980800000  ETHUSD  157.10  158.10  156.87  158.04
# ...                             ...     ...     ...     ...     ...     ...
# 2016-09-05 17:00:00      1462813200  ETHUSD    9.83    9.83    9.48    9.49
# 2016-09-05 16:00:00      1462809600  ETHUSD    9.99    9.99    9.79    9.83
# 2016-09-05 15:00:00      1462806000  ETHUSD   10.00   10.00    9.99    9.99
# 2016-09-05 14:00:00      1462802400  ETHUSD    9.55   10.00    9.55   10.00
# 2016-09-05 13:00:00      1462798800  ETHUSD    0.00   12.00    0.00    9.55
#
#                           Volume
# Date
# ...

# %%
df['2020-01': '2020-02']
# Out:
#                      Unix Timestamp  Symbol    Open    High     Low   Close  \
# Date
# 2020-02-04 23:00:00   1585868400000  ETHUSD  142.64  142.64  140.19  141.56
# 2020-02-04 22:00:00   1585864800000  ETHUSD  142.67  143.03  140.86  142.64
# 2020-02-04 21:00:00   1585861200000  ETHUSD  140.60  142.80  140.19  142.67
# 2020-02-04 20:00:00   1585857600000  ETHUSD  141.04  141.16  138.00  140.60
# 2020-02-04 19:00:00   1585854000000  ETHUSD  140.67  142.52  139.70  141.04
# ...                             ...     ...     ...     ...     ...     ...
# 2020-01-01 04:00:00   1577851200000  ETHUSD  129.83  129.96  129.13  129.54
# 2020-01-01 03:00:00   1577847600000  ETHUSD  130.25  130.30  129.42  129.83
# 2020-01-01 02:00:00   1577844000000  ETHUSD  129.95  130.58  129.95  130.25
# 2020-01-01 01:00:00   1577840400000  ETHUSD  128.11  130.01  128.11  129.95
# 2020-01-01 00:00:00   1577836800000  ETHUSD  128.84  128.84  128.07  128.11
#
#                           Volume
# Date
# ...

# %%
df['2020-01': '2020-02']['Close'].mean()
# Out:
# 201.7669318181818

# %%
df['2020-01': '2020-02']['Close'].head(50)
# Out:
# Date
# 2020-02-04 23:00:00    141.56
# 2020-02-04 22:00:00    142.64
# 2020-02-04 21:00:00    142.67
# 2020-02-04 20:00:00    140.60
# 2020-02-04 19:00:00    141.04
# 2020-02-04 18:00:00    140.67
# 2020-02-04 17:00:00    145.60
# 2020-02-04 16:00:00    143.83
# 2020-02-04 15:00:00    139.34
# 2020-02-04 14:00:00    139.40
# 2020-02-04 13:00:00    136.58
# 2020-02-04 12:00:00    137.48
# 2020-02-04 11:00:00    137.97
# 2020-02-04 10:00:00    137.47
# 2020-02-04 09:00:00    137.36
# 2020-02-04 08:00:00    137.55
# 2020-02-04 07:00:00    137.71
# 2020-02-04 06:00:00    137.49
# 2020-02-04 05:00:00    136.41
# 2020-02-04 04:00:00    136.38
# 2020-02-04 03:00:00    136.60
# 2020-02-04 02:00:00    136.51
# 2020-02-04 01:00:00    135.65
# 2020-02-04 00:00:00    136.57
# 2020-01-04 23:00:00    136.00
# 2020-01-04 22:00:00    133.77
# 2020-01-04 21:00:00    132.17
# 2020-01-04 20:00:00    132.39
# 2020-01-04 19:00:00    130.14
# 2020-01-04 18:00:00    129.70
# 2020-01-04 17:00:00    129.77
# ...

# %%
df['2020-01-01']['High'].max()
# Out:
# C:\Users\indro\AppData\Local\Temp\ipykernel_9724\3485283041.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2020-01-01']['High'].max()
# 132.57

# %%
highs = df['High'].resample('M').max()
#The code is attempting to resample the 'High' column of the DataFrame 'df' by daily (D) intervals and take the maximum value for each day.

#Resampling is a technique used to change the frequency of time-series data. In this case, it is being used to aggregate the data in the 'High' column to the daily level, by taking the maximum value for each day. The resulting DataFrame will have a DatetimeIndex with daily frequency, and the values for each day will be the maximum of the 'High' column for that day.

#For example, if the original DataFrame 'df' has hourly data for a month, and the 'High' column contains the highest value for each hour, the code above would aggregate that data to daily level, by taking the highest value for each day.

# %%
# %matplotlib inline

# %%
highs.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df.resample('M').mean().dropna()    #mean of all the ethereum data value
# Out:
# C:\Users\indro\AppData\Local\Temp\ipykernel_9724\237719908.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.resample('M').mean().dropna()
#             Unix Timestamp        Open        High         Low       Close  \
# Date
# 2016-01-31    1.472692e+09   11.813571   11.873095   11.754226   11.806310
# 2016-02-29    1.472779e+09   11.522381   11.580000   11.446190   11.506012
# 2016-03-31    1.472865e+09   11.374821   11.462619   11.308095   11.385060
# 2016-04-30    1.472952e+09   11.519881   11.572083   11.470298   11.519226
# 2016-05-31    1.466372e+09   12.126266   12.206699   12.049936   12.130353
# 2016-06-30    1.468392e+09   13.645133   13.817200   13.470783   13.640483
# 2016-07-31    1.470270e+09   12.197212   12.283606   12.117644   12.198862
# ...

# %%
mean_of_Eth = df.resample('M').mean().dropna()
# Out:
# C:\Users\indro\AppData\Local\Temp\ipykernel_9724\1685672396.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_of_Eth = df.resample('M').mean().dropna()

# %%
mean_of_Eth.plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
aggregate = df.resample('W').agg({'Close':'mean', 'High':'max', 'Low':'min', 'Volume':'sum'}).dropna().head(50)

# %%
aggregate.plot()
# Out:
# <AxesSubplot: xlabel='Date'>
