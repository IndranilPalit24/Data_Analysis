# %%
import os
import pandas as pd
from matplotlib import pyplot as plt

# %%
bowling_figures = pd.read_csv("E:\Kaggle DB\Extracted\IPL\Best Bowling Figures.csv")
bowling_figures
# Out:
#              Player  Overs  Mdns  Runs  Wkts   Econ          Team  \
# 0         AS Joseph    3.4     1    12     6   3.27        Mumbai
# 1     Sohail Tanvir    4.0     0    14     6   3.50        Royals
# 2           A Zampa    4.0     0    19     6   4.75   Supergiants
# 3          A Kumble    3.1     1     5     5   1.57           RCB
# 4         JJ Bumrah    4.0     1    10     5   2.50        Mumbai
# 5          I Sharma    3.0     0    12     5   4.00      Chargers
# 6        SL Malinga    3.4     1    13     5   3.54        Mumbai
# 7        AS Rajpoot    4.0     0    14     5   3.50      Kings XI
# 8        AD Russell    2.0     0    15     5   7.50           KKR
# 9         RA Jadeja    4.0     0    16     5   4.00   Super Kings
# 10      JP Faulkner    4.0     1    16     5   4.00        Royals
# 11         A Mishra    4.0     0    17     5   4.25    Daredevils
# 12           AJ Tye    4.0     0    17     5   4.25     Guj Lions
# ...

# %%
Best_catchers = pd.read_csv("E:\Kaggle DB\Extracted\IPL\Best Catchers.csv")
Best_catchers
# Out:
#               Player       Span    Mat   Inns     Ct  Max  Ct/Inn
# 0           SK Raina  2008-2021  205.0  204.0  109.0  3.0   0.534
# 1         KA Pollard  2010-2022  189.0  189.0  103.0  2.0   0.544
# 2          RG Sharma  2008-2022  227.0  227.0   97.0  3.0   0.427
# 3            V Kohli  2008-2022  223.0  221.0   93.0  2.0   0.420
# 4           S Dhawan  2008-2022  206.0  206.0   92.0  3.0   0.446
# 5     AB de Villiers  2008-2021  184.0  130.0   90.0  3.0   0.692
# 6          RA Jadeja  2008-2022  210.0  209.0   88.0  4.0   0.421
# 7           DJ Bravo  2008-2022  161.0  160.0   80.0  3.0   0.500
# 8          MK Pandey  2008-2022  160.0  160.0   78.0  3.0   0.487
# 9          DA Warner  2009-2022  162.0  161.0   74.0  4.0   0.459
# 10      F du Plessis  2012-2022  116.0  115.0   70.0  4.0   0.608
# 11         AM Rahane  2008-2022  158.0  158.0   61.0  2.0   0.386
# 12         DA Miller  2012-2022  105.0  105.0   59.0  4.0   0.561
# ...

# %%
highest_total = pd.read_csv("E:\Kaggle DB\Extracted\IPL\Highest totals by a Team.csv")
highest_total
# Out:
#             Team  Score  Overs     RR  Inns      Opposition        Ground  \
# 0            RCB  263/5   20.0  13.15     1      v Warriors     Bengaluru
# 1            RCB  248/3   20.0  12.40     1     v Guj Lions     Bengaluru
# 2    Super Kings  246/5   20.0  12.30     1        v Royals       Chennai
# 3            KKR  245/6   20.0  12.25     1      v Kings XI        Indore
# 4    Super Kings  240/5   20.0  12.00     1      v Kings XI        Mohali
# 5            RCB  235/1   20.0  11.75     1        v Mumbai      Wankhede
# 6         Mumbai  235/9   20.0  11.75     1     v Sunrisers     Abu Dhabi
# 7       Kings XI  232/2   20.0  11.60     1           v RCB    Dharamsala
# 8            KKR  232/2   20.0  11.60     1        v Mumbai  Eden Gardens
# 9     Daredevils  231/4   20.0  11.55     1      v Kings XI         Delhi
# 10      Kings XI  231/4   20.0  11.55     1   v Super Kings       Cuttack
# 11     Sunrisers  231/2   20.0  11.55     1           v RCB     Hyderabad
# ...

# %%
most_runs_in_innings = pd.read_csv("E:\Kaggle DB\Extracted\IPL\Most Runs in an Innings.csv")
most_runs_in_innings
# Out:
#               Player  Runs  Balls  4s  6s      SR          Team  \
# 0           CH Gayle  175*     66  13  17  265.15           RCB
# 1        BB McCullum  158*     73  10  13  216.43           KKR
# 2          Q de Kock  140*     70  10  10  200.00  Super Giants
# 3     AB de Villiers  133*     59  19   4  225.42           RCB
# 4           KL Rahul  132*     69  14   7  191.30      Kings XI
# 5     AB de Villiers  129*     52  10  12  248.07           RCB
# 6           CH Gayle  128*     62   7  13  206.45           RCB
# 7            RR Pant  128*     63  15   7  203.17    Daredevils
# 8            M Vijay   127     56   8  11  226.78   Super Kings
# 9          DA Warner   126     59  10   8  213.55     Sunrisers
# 10        JC Buttler   124     64  11   8  193.75        Royals
# 11          V Sehwag   122     58  12   8  210.34      Kings XI
# 12       PC Valthaty  120*     63  19   2  190.47      Kings XI
# 13          V Sehwag   119     56  13   6  212.50    Daredevils
# ...

# %%
most_Runs = pd.read_csv("E:\Kaggle DB\Extracted\IPL\Most Runs.csv")
most_Runs
# Out:
#             Player       Span    Mat   Inns    NO    Runs    HS    Ave  \
# 0          V Kohli  2008-2022  223.0  215.0  32.0  6624.0   113  36.19
# 1         S Dhawan  2008-2022  206.0  205.0  27.0  6244.0  106*  35.07
# 2        DA Warner  2009-2022  162.0  162.0  22.0  5881.0   126  42.00
# 3        RG Sharma  2008-2022  227.0  222.0  28.0  5879.0  109*  30.30
# 4         SK Raina  2008-2021  205.0  200.0  30.0  5528.0  100*  32.51
# 5   AB de Villiers  2008-2021  184.0  170.0  40.0  5162.0  133*  39.70
# 6         MS Dhoni  2008-2022  234.0  206.0  79.0  4978.0   84*  39.19
# 7         CH Gayle  2009-2021  142.0  141.0  16.0  4965.0  175*  39.72
# 8       RV Uthappa  2008-2022  205.0  197.0  17.0  4952.0    88  27.51
# 9       KD Karthik  2008-2022  229.0  208.0  45.0  4376.0   97*  26.84
# 10       G Gambhir  2008-2018  154.0  152.0  16.0  4217.0    93  31.00
# 11       AT Rayudu  2010-2022  188.0  175.0  31.0  4190.0  100*  29.09
# ...

# %%
most_Wickets = pd.read_csv("E:\Kaggle DB\Extracted\IPL\Most wickets.csv")
most_Wickets
# Out:
#              Player       Span    Mat   Inns  Overs  Mdns    Runs   Wkts  \
# 0          DJ Bravo  2008-2022  161.0  158.0  519.5   3.0  4360.0  183.0
# 1        SL Malinga  2009-2019  122.0  122.0  471.1   8.0  3365.0  170.0
# 2         YS Chahal  2013-2022  131.0  130.0  476.0   4.0  3624.0  166.0
# 3          A Mishra  2008-2021  154.0  154.0  540.5   6.0  3976.0  166.0
# 4         PP Chawla  2008-2021  165.0  164.0  545.4   2.0  4301.0  157.0
# 5          R Ashwin  2009-2022  184.0  181.0  650.0   4.0  4534.0  157.0
# 6           B Kumar  2011-2022  146.0  146.0  543.4  11.0  3971.0  154.0
# 7         SP Narine  2012-2022  148.0  147.0  576.1   3.0  3820.0  152.0
# 8   Harbhajan Singh  2008-2021  163.0  160.0  569.2   6.0  4030.0  150.0
# 9         JJ Bumrah  2013-2022  120.0  120.0  457.0   8.0  3379.0  145.0
# 10         UT Yadav  2010-2022  133.0  132.0  468.2   5.0  3918.0  135.0
# 11        RA Jadeja  2008-2022  210.0  181.0  534.1   2.0  4064.0  132.0
# ...

# %%
files = [file for file in os.listdir("E:\Kaggle DB\Extracted/IPL")]

cricket_data = pd.DataFrame()

for file in files:
    df = pd.read_csv("E:\Kaggle DB\Extracted/IPL/"+file)

    cricket_data = pd.concat([cricket_data, df])


cricket_data.to_csv('E:\Kaggle DB\Extracted/IPL/cricket_Data.csv', index=False)

# %%
ipl_tournament = pd.read_csv('E:\Kaggle DB\Extracted\IPL/cricket_data.csv')
ipl_tournament
# Out:
#                Player  Overs  Mdns    Runs   Wkts   Econ          Team  \
# 0           AS Joseph    3.4   1.0    12.0    6.0   3.27        Mumbai
# 1       Sohail Tanvir    4.0   0.0    14.0    6.0   3.50        Royals
# 2             A Zampa    4.0   0.0    19.0    6.0   4.75   Supergiants
# 3            A Kumble    3.1   1.0     5.0    5.0   1.57           RCB
# 4           JJ Bumrah    4.0   1.0    10.0    5.0   2.50        Mumbai
# 5            I Sharma    3.0   0.0    12.0    5.0   4.00      Chargers
# 6          SL Malinga    3.4   1.0    13.0    5.0   3.54        Mumbai
# 7          AS Rajpoot    4.0   0.0    14.0    5.0   3.50      Kings XI
# 8          AD Russell    2.0   0.0    15.0    5.0   7.50           KKR
# 9           RA Jadeja    4.0   0.0    16.0    5.0   4.00   Super Kings
# 10        JP Faulkner    4.0   1.0    16.0    5.0   4.00        Royals
# 11           A Mishra    4.0   0.0    17.0    5.0   4.25    Daredevils
# ...

# %%
ipl_tournament.loc[0]
# Out:
# Player          AS Joseph
# Overs                 3.4
# Mdns                  1.0
# Runs                 12.0
# Wkts                  6.0
# Econ                 3.27
# Team               Mumbai
# Opposition    v Sunrisers
# Ground          Hyderabad
# Match Date     2019-04-06
# Scorecard             T20
# Span                  NaN
# Mat                   NaN
# Inns                  NaN
# Ct                    NaN
# Max                   NaN
# Ct/Inn                NaN
# Score                 NaN
# RR                    NaN
# Balls                 NaN
# 4s                    NaN
# 6s                    NaN
# SR                    NaN
# NO                    NaN
# HS                    NaN
# Ave                   NaN
# BF                    NaN
# 100                   NaN
# 50                    NaN
# 0                     NaN
# BBI                   NaN
# 4                     NaN
# 5                     NaN
# Name: 0, dtype: object
