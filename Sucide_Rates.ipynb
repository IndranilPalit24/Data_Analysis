# %% [markdown]
# # Database for finding the suicide rates in the world

# %%
import pandas as pd

# %%
data_set = pd.read_csv(r"E:\Kaggle DB\Extracted\Sucide rates\master.csv", index_col = "country")

# %%
data_set
# Out:
#                           year     sex          age  suicides_no  population  \
# country
# Albania                   1987    male  15-24 years         21.0      312900
# Albania                   1987    male  35-54 years         16.0      308000
# Albania                   1987  female  15-24 years         14.0      289700
# Albania                   1987    male    75+ years          1.0       21800
# Albania                   1987    male  25-34 years          9.0      274300
# ...                        ...     ...          ...          ...         ...
# Ukraine                   2017  female    75+ years        256.0    44831135
# United Kingdom            2017  female    75+ years        104.0    66058859
# United States of America  2017  female    75+ years        501.0   325122128
# Uruguay                   2017  female    75+ years         14.0     3422200
# Uzbekistan                2017  female    75+ years          3.0    32388600
#
# ...

# %%
data_set.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years         21.0      312900
# 1  Albania  1987    male  35-54 years         16.0      308000
# 2  Albania  1987  female  15-24 years         14.0      289700
# 3  Albania  1987    male    75+ years          1.0       21800
# 4  Albania  1987    male  25-34 years          9.0      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN     2,15,66,24,900
# 1               5.19  Albania1987           NaN     2,15,66,24,900
# 2               4.83  Albania1987           NaN     2,15,66,24,900
# 3               4.59  Albania1987           NaN     2,15,66,24,900
# 4               3.28  Albania1987           NaN     2,15,66,24,900
#
#    gdp_per_capita ($)       generation
# 0               796.0     Generation X
# 1               796.0           Silent
# 2               796.0     Generation X
# ...

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31756 entries, 0 to 31755
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             31756 non-null  object
#  1   year                31756 non-null  int64
#  2   sex                 31756 non-null  object
#  3   age                 31756 non-null  object
#  4   suicides_no         30556 non-null  float64
#  5   population          31756 non-null  int64
#  6   suicides/100k pop   31756 non-null  float64
#  7   country-year        31756 non-null  object
#  8   HDI for year        12300 non-null  float64
#  9    gdp_for_year ($)   31756 non-null  object
#  10  gdp_per_capita ($)  31756 non-null  float64
#  11  generation          31756 non-null  object
# dtypes: float64(4), int64(2), object(6)
# memory usage: 2.9+ MB

# %%
data_set.tail(2)
# Out:
#           country  year     sex        age  suicides_no  population  \
# 31754     Uruguay  2017  female  75+ years         14.0     3422200
# 31755  Uzbekistan  2017  female  75+ years          3.0    32388600
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# 31754           0.409094     Uruguay2017      0.816745        64233966861
# 31755           0.009263  Uzbekistan2017      0.691258        62081323299
#
#        gdp_per_capita ($)       generation
# 31754        18690.893840  G.I. Generation
# 31755         1916.764642  G.I. Generation

# %% [markdown]
# # Finding the country  dataset on Israel

# %%
setting_country = data_set.country == "Israel"
setting_year = data_set.year == 2014
male = data_set.sex == 'male'
female = data_set.sex == 'female'
setting_age = data_set.year.between(2012,2014)

f_df = data_set.loc[setting_country & setting_age & (male | female),['country','year', 'sex', 'age', 'suicides_no']]
f_df
# Out:
#       country  year   sex          age  suicides_no
# 12740  Israel  2012  male    75+ years         33.0
# 12741  Israel  2012  male  55-74 years         93.0
# 12742  Israel  2012  male  35-54 years        131.0
# 12743  Israel  2012  male  25-34 years         57.0
# 12744  Israel  2012  male  15-24 years         32.0
# 12745  Israel  2012  male    75+ years          9.0
# 12746  Israel  2012  male  55-74 years         24.0
# 12747  Israel  2012  male  25-34 years         17.0
# 12748  Israel  2012  male  15-24 years         13.0
# 12749  Israel  2012  male  35-54 years         18.0
# 12750  Israel  2012  male   5-14 years          3.0
# 12751  Israel  2012  male   5-14 years          0.0
# 12752  Israel  2013  male    75+ years         34.0
# 12753  Israel  2013  male  55-74 years         71.0
# 12754  Israel  2013  male  35-54 years        102.0
# 12755  Israel  2013  male  25-34 years         47.0
# 12756  Israel  2013  male    75+ years         12.0
# ...

# %% [markdown]
# # Suicide No's in Israel

# %%
f_df.sum().suicides_no
# Out:
# 1184.0

# %%
data_set.isnull().any()
# Out:
# country               False
# year                  False
# sex                   False
# age                   False
# suicides_no            True
# population            False
# suicides/100k pop     False
# country-year          False
# HDI for year           True
#  gdp_for_year ($)     False
# gdp_per_capita ($)    False
# generation            False
# dtype: bool

# %%
data_set['HDI for year']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 31751    0.785458
# 31752    0.914735
# 31753    0.918620
# 31754    0.816745
# 31755    0.691258
# Name: HDI for year, Length: 31756, dtype: float64
