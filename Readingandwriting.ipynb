# %%
import pandas as pd
import matplotlib_inline

# %%
dataframe = pd.read_csv("E:\Kaggle DB\Extracted\Coders Survey\survey_results_public.csv", index_col = "ResponseId")

# %%
pd.set_option('display.max_columns',85)
dataframe
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
dataframe.shape
# Out:
# (83439, 48)

# %%
filt = (dataframe['Country']=='India')
india_df = dataframe.loc[filt]
india_df.head()
# Out:
#                                         MainBranch          Employment  \
# ResponseId
# 9                   I am a developer by profession  Employed part-time
# 23          I am a student who is learning to code  Student, full-time
# 40          I am a student who is learning to code  Student, part-time
# 50          I am a student who is learning to code  Student, full-time
# 53                  I am a developer by profession  Employed full-time
#
#            Country US_State UK_Country  \
# ResponseId
# 9            India      NaN        NaN
# 23           India      NaN        NaN
# 40           India      NaN        NaN
# 50           India      NaN        NaN
# 53           India      NaN        NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 9                Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 23          Some college/university study without earning ...   5 - 10 years
# ...

# %%
india_df.to_csv('E:\Kaggle DB\Extracted\Coders Survey\modified_data.csv')
#This creates a new CSV wherein the filtered data namely all the data for India that has been created above has been 
#displayed

# %%
india_df.to_csv('E:\Kaggle DB\Extracted\Coders Survey\modified_data.tsv', sep = '\t')
#This india df file extension is changed to .tsv format and then it is seperated by \t

# %%
# To check the data in the excel file we need to install excel version by typing the command 
#pip install xlwt openpyxl xlrd this will install all the version through which you will be able
#to download the file in the Excel format

# %%
india_df.to_excel('E:\Kaggle DB\Extracted\Coders Survey\modified_data.xlsx')

#This line changes and downloads the file in the xlsx fromat viz excel format

# %%
# Now lets say we want to read the excel data back in Jupyter itself, how can I do it?
test = pd.read_excel('E:\Kaggle DB\Extracted\Coders Survey\modified_data.xlsx', index_col = "ResponseId")
test

#You can use the simliar setup with other file formats namely .csv, .tsv. Make sure to change pd.read_<fileformat>
# Out:
#                                         MainBranch          Employment  \
# ResponseId
# 9                   I am a developer by profession  Employed part-time
# 23          I am a student who is learning to code  Student, full-time
# 40          I am a student who is learning to code  Student, part-time
# 50          I am a student who is learning to code  Student, full-time
# 53                  I am a developer by profession  Employed full-time
# ...                                            ...                 ...
# 83400               I am a developer by profession  Employed full-time
# 83407       I am a student who is learning to code  Student, full-time
# 83411       I am a student who is learning to code  Student, part-time
# 83412               I am a developer by profession  Employed full-time
# 83418               I am a developer by profession  Student, full-time
#
#            Country  US_State  UK_Country  \
# ResponseId
# 9            India       NaN         NaN
# ...

# %%
test.head()
# Out:
#                                         MainBranch          Employment  \
# ResponseId
# 9                   I am a developer by profession  Employed part-time
# 23          I am a student who is learning to code  Student, full-time
# 40          I am a student who is learning to code  Student, part-time
# 50          I am a student who is learning to code  Student, full-time
# 53                  I am a developer by profession  Employed full-time
#
#            Country  US_State  UK_Country  \
# ResponseId
# 9            India       NaN         NaN
# 23           India       NaN         NaN
# 40           India       NaN         NaN
# 50           India       NaN         NaN
# 53           India       NaN         NaN
#
#                                                       EdLevel     Age1stCode  \
# ResponseId
# 9                Bachelor’s degree (B.A., B.S., B.Eng., etc.)  18 - 24 years
# 23          Some college/university study without earning ...   5 - 10 years
# ...

# %%
india_df.to_json('E:\Kaggle DB\Extracted\Coders Survey\modified_data.json', orient = 'records', lines=True)

#

# %%
# Now we want to install two other adapters namely SQL Alchemy and psycopg2-binary because 

#SQLAlchemy is the Python SQL toolkit and Object Relational Mapper that gives application 
#developers the full power and flexibility of SQL.

#AND

#Psycopg is the most popular PostgreSQL database adapter for the Python programming language. 
#Its main features are the complete implementation 
#of the Python DB API 2.0 specification and the thread safety (several threads can share the same connection). 
#It was designed for heavily multi-threaded applications that create and destroy lots of cursors 
#and make a large number of concurrent “INSERT”s or “UPDATE”s.

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
#engine = create_engine('<Your local host>') # example -> 'postgresql://dbuser:dbpass@localhost:5432/<data_title>'

# %%
#this will create the database with the <data_title> that you have provided

# %%
#india_df.to_sql('sample_table', engine, if_exists = 'replace')

#this will transfer all data from df in python to SQL database and then lets say if you want to check that if the data is
#already there or not then use if_exists method, this method will check that if the data is already there or not 
#if not it will print otherwise will replace

# %%
#sql_df = pd.read_sql('sample_table',engine, index_col = 'ResposeId')

#This will read the SQL Data from SQL to Python(Jupyter)

# %%
#sql_df = pd.read_sql_query('SELECT * FROM sample_table', engine, index_col = 'ResponseId')


#This will read all the data as how you will write in the postgres SQL 
# For exmaple you might write : SELECT * FROM <TABLE_NAME> in SQL
#This method actually writes it for you from Jupyter
